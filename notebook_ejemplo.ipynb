# %% [markdown]
# Primero importo mis librerías de turno.

# %%
from glob import glob
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("bmh")
# %matplotlib inline

# %% [markdown]
# # Lectura de datos

# %% [markdown]
# Leemos los datos de la carpeta ***Data/***
#
# * lista

# %%
files = glob(os.path.join("Data", "*"))

# %%
for f in sorted(files):
    df = pd.read_csv(f,index_col=0)
    df.plot()

# %%
# %matplotlib notebook

# %%
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="843">

# %% [markdown]
# El dato 40 del fichero 9 parece erróneo según la fórmula:
#
# $$ x = y^{2} $$

# %% [markdown]
# <div class="alert alert-danger">
#
#  Revisar esto en detalle, ver más abajo.
#
# </div>

# %% [markdown]
# # Análisis más fino del fichero 9 dibujando columna a columna

# %% [markdown]
# Vamos a ver el gráfico columna a columna de forma interactiva:

# %%
from ipywidgets import interact
# %matplotlib inline

def plot(col):
    df.loc[:, col].plot(figsize=(12,6))
    
interact(plot, col=df.columns.tolist())
# Out:
# interactive(children=(Dropdown(description='col', options=('col01', 'col02', 'col03', 'col04', 'col05', 'col06', 'col07', 'col08', 'col09', 'col10'), value='col01'), Output()), _dom_classes=('widget-interact',))
# <function __main__.plot>

# %% [markdown]
# Por lo que puedo ver, en la columna 8 hay un dato erróneo.
